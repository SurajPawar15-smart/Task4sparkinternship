# %% [markdown]
# **GRIP : The Sparks Foundation ( Data Science and Business Analytics Intern )**

# %% [markdown]
# **Name: Suraj Sanjeev Pawar**

# %% [markdown]
# **Task 4: Exploratory Data Analysis Terrorism  on dataset ‘Global Terrorism’**

# %% [markdown]
# ***Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism***

# %% [markdown]
# ● ***Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’.<br>***
# ● ***As a security/defense analyst, try to find out the hot zone of terrorism.<br>***
# ● ***What all security issues and insights you can derive by EDA?<br>***

# %% [markdown]
# ***Importing  required libraries***

# %%
#import the libraries. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Read the Dataset using Dataframe***

# %%
#importing the data 
df = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,31,33,61,62,76,79,94,96,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ***shape of the given dataset***

# %%
#to find the shape of dataframe
print(df.shape)
# Out:
# (27672, 135)

# %% [markdown]
# ***to fine the type of the dataset***

# %%
#to find the type of dataset
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ***finding the first five rows in dataset***

# %%
#to find the first row to the dataframe
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ***finding the last five rows in dataset***

# %%
#to find the last five rows in dataframe
df.tail()
# Out:
#             eventid  ...                                            related
# 27667  198603260049  ...  198603260049, 198603260001, 198603260002, 1986...
# 27668  198603260050  ...  198603260050, 198603260001, 198603260002, 1986...
# 27669  198603260051  ...  198603260051, 198603260001, 198603260002, 1986...
# 27670  198603260052  ...  198603260052, 198603260001, 198603260002, 1986...
# 27671  198603260053  ...                                                NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ***find the correlation***

# %%
#to find the correlation in dataframe
df.corr()
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999931 -0.046981  ...  0.046552 -0.187472 -0.040758
# iyear      0.999931  1.000000 -0.055762  ...  0.046590 -0.187623 -0.040714
# imonth    -0.046981 -0.055762  1.000000  ... -0.012626  0.027234 -0.009799
# iday      -0.015670 -0.015929  0.012848  ... -0.005983  0.023528  0.003266
# extended  -0.053917 -0.053878  0.005912  ...  0.024772  0.034634  0.030679
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased  0.093427  0.093115  0.012610  ...  0.015357  0.002322  0.016970
# INT_LOG    0.048472  0.048514 -0.013513  ...  0.994256  0.078512  0.830773
# INT_IDEO   0.046552  0.046590 -0.012626  ...  1.000000  0.113323  0.834348
# INT_MISC  -0.187472 -0.187623  0.027234  ...  0.113323  1.000000  0.320812
# INT_ANY   -0.040758 -0.040714 -0.009799  ...  0.834348  0.320812  1.000000
#
# [78 rows x 78 columns]

# %% [markdown]
# ***to find the columns name in dataset***

# %%
#to find the name of columns in dataframe
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ***finding the min value in the dataset***

# %%
#to find the min on each column of the dataset
df.min()
# Out:
# eventid      197000000001
# iyear                1970
# imonth                  0
# iday                    0
# extended                0
#                  ...
# nreleased             -99
# INT_LOG                -9
# INT_IDEO               -9
# INT_MISC               -9
# INT_ANY                -9
# Length: 80, dtype: object

# %% [markdown]
# ***finding the max value in the dataset***

# %%
#to find the max on each column of the dataset
df.max()
# Out:
# eventid      198603260053
# iyear                1987
# imonth                 12
# iday                   31
# extended                1
#                  ...
# nreleased             390
# INT_LOG                 1
# INT_IDEO                1
# INT_MISC                1
# INT_ANY                 1
# Length: 80, dtype: object

# %% [markdown]
# ***slicing using iloc for integer number only***

# %%
#to get data using slicing using iloc 
df.iloc[2:8]
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 5  197001010002   1970       1     1  ...     -9.0       0.0    -9.0      NaN
# 6  197001020001   1970       1     2  ...      0.0       0.0     0.0      NaN
# 7  197001020002   1970       1     2  ...     -9.0       0.0    -9.0      NaN
#
# [6 rows x 135 columns]

# %% [markdown]
# ***find any unique or dublicate value in dataset***

# %%
#to get info about the unique values in dataframe
df.nunique()
# Out:
# eventid       27672
# iyear            18
# imonth           13
# iday             32
# approxdate       19
#               ...
# INT_LOG           3
# INT_IDEO          3
# INT_MISC          3
# INT_ANY           3
# related         592
# Length: 135, dtype: int64

# %% [markdown]
# ***Statistical Properties of Dataset***

# %%
#to summarize the statistical details of the dataframe
df.describe()
# Out:
#             eventid         iyear  ...      INT_MISC       INT_ANY
# count  2.767200e+04  27672.000000  ...  27671.000000  27671.000000
# mean   1.980418e+11   1980.354257  ...      0.198945     -2.423331
# std    3.922739e+08      3.924702  ...      0.696156      4.374893
# min    1.970000e+11   1970.000000  ...     -9.000000     -9.000000
# 25%    1.978103e+11   1978.000000  ...      0.000000     -9.000000
# 50%    1.981071e+11   1981.000000  ...      0.000000      0.000000
# 75%    1.984012e+11   1984.000000  ...      0.000000      1.000000
# max    1.986033e+11   1987.000000  ...      1.000000      1.000000
#
# [8 rows x 78 columns]

# %% [markdown]
# ***to summarize the dataset***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27672 entries, 0 to 27671
# Columns: 135 entries, eventid to related
# dtypes: float64(71), int64(7), object(57)
# memory usage: 28.5+ MB

# %% [markdown]
# ***check weather the null value in dataset***

# %%
#to return the null values in the dataframe
df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    27651
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       25826
# Length: 135, dtype: int64

# %% [markdown]
# ***check weather the duplicate value is present***

# %%
#Check for duplication 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***Dataset are change the names of columns***

# %%
#display the name of the Column present in our dataframe
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ***Columns name become this below***

# %%
#changing the name of the old columns to new ones.
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
#we only takes an important columns which is required only in our dataframe.
df1=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
df1.head()
# Out:
#    Year  Month  Day  ...                  Target_type Weapon_type Motive
# 0  1970      7    2  ...  Private Citizens & Property     Unknown    NaN
# 1  1970      0    0  ...      Government (Diplomatic)     Unknown    NaN
# 2  1970      1    0  ...          Journalists & Media     Unknown    NaN
# 3  1970      1    0  ...      Government (Diplomatic)  Explosives    NaN
# 4  1970      1    0  ...      Government (Diplomatic)  Incendiary    NaN
#
# [5 rows x 18 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27672 entries, 0 to 27671
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         27672 non-null  int64
#  1   Month        27672 non-null  int64
#  2   Day          27672 non-null  int64
#  3   Country      27672 non-null  object
#  4   state        27559 non-null  object
#  5   Region       27672 non-null  object
#  6   city         27671 non-null  object
#  7   latitude     26234 non-null  float64
#  8   longitude    26234 non-null  float64
#  9   AttackType   27671 non-null  object
#  10  Killed       22454 non-null  float64
#  11  Wounded      20747 non-null  float64
#  12  Target       27351 non-null  object
#  13  Summary      1058 non-null   object
#  14  Group        27671 non-null  object
#  15  Target_type  27671 non-null  object
#  16  Weapon_type  27671 non-null  object
#  17  Motive       787 non-null    object
# ...

# %% [markdown]
# ***Visualization of the Pair Plot represenatation using to find different relation among the attributes or features***

# %%
#Check the corelation between the different parameters.
sns.pairplot(df1, hue = 'Region')
plt.show()

# %% [markdown]
# ***Count of the number of Countries that are affected by Terrorist attacks are representation in the form of top five and last less attacks by terrorist***

# %%
df['Country'].value_counts().head()
# Out:
# El Salvador       3497
# United Kingdom    2415
# Peru              2231
# Colombia          1862
# United States     1851
# Name: Country, dtype: int64

# %%
df['Country'].value_counts().tail()
# Out:
# Gabon           1
# Belize          1
# Burkina Faso    1
# Soviet Union    1
# Iceland         1
# Name: Country, dtype: int64

# %%
df['Country'].value_counts()
plt.figure(figsize=(10,8))
sns.barplot(x=df['Country'].value_counts()[:20].index,y=df['Country'].value_counts()[:20].values)
plt.title('Top Countries got attacked')
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.ylabel('No. of Attacks')
plt.show()

# %% [markdown]
# ***Here, we can conclude that the no.of Attacks V/s the Countries representation of the graph as EL Salvador are high number of attacks and least by South Africa country.***

# %% [markdown]
# ***Visualization representation of the region were mostly affected by  Terrorist attacks***

# %%
print('Region were the most attacks are found: '+df['Region'].value_counts().idxmax())
# Out:
# Region were the most attacks are found: Western Europe

# %%
df['Region'].value_counts()
plt.figure(figsize=(10,8))
sns.countplot(x='Region',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ***Here, we can conclude that the Count V/s Region representation of the graph as the Region were Central America & Caribbean are of attacks and least by South Africa country.***

# %% [markdown]
# ***The Cities were more affected by terrorist attacks***

# %%
df['city'].value_counts()
# Out:
# Unknown         1760
# Belfast         1064
# San Salvador    1043
# Santiago         719
# Lima             675
#                 ...
# Alauca             1
# Shika              1
# Bovalino           1
# Anserma            1
# Baloda Bazar       1
# Name: city, Length: 5088, dtype: int64

# %%
df['city'].value_counts()
plt.figure(figsize=(10,8))
sns.barplot(x=df['city'].value_counts()[:20].index,y=df['city'].value_counts()[:20].values)
plt.title('Top Cities got attacks')
plt.xticks(rotation=90)
plt.xlabel('Cities')
plt.ylabel('No of Attacks')
plt.show()

# %% [markdown]
# ***Here,we conclude that No of Attacks V/s Cities as there are top 20 cities which got highest attacks.***

# %% [markdown]
# ***Visualization based on the Trend of attacks form 1970 to 2017 Years with the count representation***

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x='Year',data=df,palette='tab10')
plt.xticks(rotation=90)
plt.title('Terror attacks from 1970 TO 2017')
plt.show()

# %% [markdown]
# ***Here,we conclude that between Terror attacks from 1970 TO 2017 attacks.***

# %% [markdown]
# ***Visualization representation of the type of attack used by Terrorists***

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['AttackType'],order=df['AttackType'].value_counts().index,palette='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Attack Type')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ***Here,we conclude that Number of Attacks V/S Attack type as  mostly using by Bombing/Explosion are formed and least type of attack are used by Unarmed Assault.***

# %% [markdown]
# ***Visualization based on the Weapons which are used for supporting for the type of attack***

# %%
df['Weapon_type'].value_counts()
plt.figure(figsize=(10,8))
color=['blue','red','green','orange']
sns.barplot(x=df['Weapon_type'].value_counts()[:20].index,y=df['Weapon_type'].value_counts()[:20].values , palette=color)
plt.title('Weapons Usage')
plt.xticks(rotation=90)
plt.xlabel('Weapon used')
plt.ylabel('No fo times')
plt.show()

# %% [markdown]
# ***Weapon used for supporting the attack***

# %%
df['Target_type'].value_counts()
# Out:
# Business                          5271
# Military                          4423
# Private Citizens & Property       4408
# Government (General)              3174
# Police                            2769
# Utilities                         1536
# Government (Diplomatic)           1282
# Transportation                    1201
# Journalists & Media                709
# Educational Institution            642
# Airports & Aircraft                606
# Religious Figures/Institutions     365
# Terrorists/Non-State Militia       279
# Unknown                            273
# Telecommunication                  231
# Violent Political Party            115
# NGO                                 81
# Maritime                            80
# Food or Water Supply                79
# Tourists                            72
# Abortion Related                    66
# Other                                9
# Name: Target_type, dtype: int64

# %% [markdown]
# ***Visualization based on the number of the Attacks targets and Targets Categories***

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['Target_type'],order=df['Target_type'].value_counts().index,palette='rainbow')
plt.xticks(rotation=90)
plt.xlabel('Targets')
plt.ylabel('No of Targets')
plt.show()

# %% [markdown]
# ***Here,we can conclude that No of Targets V/s the Targets are mostly by using Terrorist target towards the Business person and least by Abortion Related other etc.***

# %% [markdown]
# ***Visualization on the bases of the Name of the group attacks  and No.of attacks by Terrorist***

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['Group'].value_counts()[:20].index,y=df['Group'].value_counts()[:20].values,palette='pastel')
plt.xticks(rotation=90)
plt.title('Total Group Attacks')
plt.xlabel('Group Name')
plt.ylabel('Total no. of attacks')
plt.show()

# %% [markdown]
# ***here,we conclude that the Total No.of attacks V/s the Group Name as there are Unknown group attack mostly and least by the National Liberation Armay of Colombia(ELN).***

# %% [markdown]
# ***Thank you,The Sparks Foundation***
